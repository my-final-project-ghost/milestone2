# %% [markdown]
# <h1>Introduction</h1>
# <p>This dataset imported from Kaggle here we will try to analsis this dataset, answering some bussines questions to satisfy the client</p>

# %% [markdown]
# Kaggle dataset link https://www.kaggle.com/gregorut/videogamesales

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
sns.set(rc={'figure.figsize':[15,15]},font_scale=1.4)

# %%
df=pd.read_csv('data.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
df = df[df['Year'].notna()]
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df['Global_Sales'].max()
# Out:
# 82.74

# %%
df.groupby('Name').describe()

# %%
try:
    df['Year'] = df['Year'].astype(int)
except:
    df['Year']=NaN
# Out:
# C:\Users\Commandor\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# type Error in years, years must be integers not float:)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16327 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16327 non-null  int64
#  1   Name          16327 non-null  object
#  2   Platform      16327 non-null  object
#  3   Year          16327 non-null  int32
#  4   Genre         16327 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16327 non-null  float64
#  7   EU_Sales      16327 non-null  float64
#  8   JP_Sales      16327 non-null  float64
#  9   Other_Sales   16327 non-null  float64
#  10  Global_Sales  16327 non-null  float64
# dtypes: float64(5), int32(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df['Year']
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16593    2002
# 16594    2003
# 16595    2008
# 16596    2010
# 16597    2003
# Name: Year, Length: 16327, dtype: int32

# %% [markdown]
# <p>What is the most selling platform ?</p>
# <p>Top selling game in all years ?</p>
# <p>which year had make a big diffrences and makes alot of sales?</p>
# <p>best selling company and what's genere it is specialized ?</p>
# <p>What Genere does Europe like most?</p>
# <p>What Genere does Japan like most?</p>
# <p>What Genere does North America like most?</p>
# <p>What Genere does all people love  most?</p>
# <p>is publisher of the game affect the selling ?</p>
# <p>whiich series sells the most?</p>
# <p>top hated games throught all years ?</p>
# <p>minimum year all games have been sold?</p>
# <p>in last 10 years which genere are popular to publish a game ?</p>
# <p>top publisher in last 10 years ?</p>
# <p>what is top 10 games </p>

# %%
df['Platform'].value_counts()
# Out:
# DS      2133
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1235
# PSP     1197
# PS      1189
# PC       943
# GBA      811
# XB       803
# GC       542
# 3DS      500
# PSV      412
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
df.groupby('Platform')['Global_Sales'].describe()
# Out:
#            count      mean       std   min     25%    50%     75%    max
# Platform
# 2600       116.0  0.746293  0.955571  0.07  0.3050  0.475  0.7800   7.81
# 3DO          3.0  0.033333  0.023094  0.02  0.0200  0.020  0.0400   0.06
# 3DS        500.0  0.492560  1.401981  0.01  0.0500  0.125  0.3500  14.35
# DC          52.0  0.307115  0.469912  0.02  0.0775  0.135  0.2975   2.42
# DS        2133.0  0.383947  1.444197  0.01  0.0500  0.110  0.2800  30.01
# GB          97.0  2.622887  5.390733  0.06  0.3000  1.180  2.1800  31.37
# GBA        811.0  0.386634  0.899298  0.01  0.0600  0.160  0.3900  15.85
# GC         542.0  0.363727  0.693107  0.01  0.0700  0.150  0.3700   7.07
# GEN         27.0  1.050370  1.492217  0.03  0.0700  0.150  1.7100   6.03
# GG           1.0  0.040000       NaN  0.04  0.0400  0.040  0.0400   0.04
# N64        316.0  0.690538  1.321415  0.01  0.1300  0.270  0.6000  11.89
# NES         98.0  2.561939  5.108195  0.06  1.0000  1.375  2.2225  40.24
# ...

# %% [markdown]
# What is the most selling platform ?
# PS2 is the most selling

# %%
sns.barplot(y='Platform',x='Global_Sales',data=df,estimator=np.sum)

# %% [markdown]
# Top selling game in all years ?

# %%
df.groupby('Name')['Global_Sales'].sum()
# Out:
# Name
# '98 Koshien                                0.41
# .hack//G.U. Vol.1//Rebirth                 0.17
# .hack//G.U. Vol.2//Reminisce               0.23
# .hack//G.U. Vol.2//Reminisce (jp sales)    0.16
# .hack//G.U. Vol.3//Redemption              0.17
#                                            ...
# thinkSMART FAMILY!                         0.03
# thinkSMART: Chess for Kids                 0.01
# uDraw Studio                               2.46
# uDraw Studio: Instant Artist               0.21
# ¡Shin Chan Flipa en colores!               0.14
# Name: Global_Sales, Length: 11360, dtype: float64

# %%
df.groupby('Genre')['Global_Sales'].sum()
# Out:
# Genre
# Action          1722.88
# Adventure        234.80
# Fighting         444.05
# Misc             797.62
# Platform         829.15
# Puzzle           242.22
# Racing           726.77
# Role-Playing     923.84
# Shooter         1026.20
# Simulation       390.16
# Sports          1309.24
# Strategy         173.43
# Name: Global_Sales, dtype: float64

# %% [markdown]
# top publisher is Avtivasion and the top genere is ACTION

# %%
df[df['Genre']=='Action']['Publisher'].value_counts()
# Out:
# Activision                 308
# Namco Bandai Games         247
# Ubisoft                    193
# THQ                        193
# Electronic Arts            182
#                           ...
# Avalon Interactive           1
# Gremlin Interactive Ltd      1
# Video System                 1
# Agatsuma Entertainment       1
# dramatic create              1
# Name: Publisher, Length: 228, dtype: int64

# %%
sns.barplot(x='Genre',y='Global_Sales',data=df,estimator=np.sum)

# %%
df[df['Publisher']=='Activision']['Global_Sales'].sum()
# Out:
# 721.41

# %%
sns.barplot(x='Publisher',y='Global_Sales',data=df,estimator=np.sum)

# %%
dd.describe()
# Out:
# Platform        2600       3DO         3DS         DC           DS         GB  \
# count     116.000000  3.000000  500.000000  52.000000  2133.000000  97.000000
# mean        0.746293  0.033333    0.492560   0.307115     0.383947   2.622887
# std         0.955571  0.023094    1.401981   0.469912     1.444197   5.390733
# min         0.070000  0.020000    0.010000   0.020000     0.010000   0.060000
# 25%         0.305000  0.020000    0.050000   0.077500     0.050000   0.300000
# 50%         0.475000  0.020000    0.125000   0.135000     0.110000   1.180000
# 75%         0.780000  0.040000    0.350000   0.297500     0.280000   2.180000
# max         7.810000  0.060000   14.350000   2.420000    30.010000  31.370000
#
# Platform         GBA          GC        GEN    GG  ...         SAT       SCD  \
# count     811.000000  542.000000  27.000000  1.00  ...  173.000000  6.000000
# mean        0.386634    0.363727   1.050370  0.04  ...    0.194162  0.311667
# ...

# %% [markdown]
# 2006 is the most selling year  and i think it's an outlier

# %%
df.groupby('Year')['Global_Sales'].max()
# Out:
# Year
# 1980     4.31
# 1981     4.50
# 1982     7.81
# 1983     3.20
# 1984    28.31
# 1985    40.24
# 1986     6.51
# 1987     4.38
# 1988    17.28
# 1989    30.26
# 1990    20.61
# 1991     4.61
# 1992    11.18
# 1993    10.55
# 1994     9.30
# 1995     5.15
# 1996    31.37
# 1997    10.95
# 1998    14.64
# 1999    23.10
# 2000     6.39
# 2001    14.98
# 2002    16.15
# 2003     7.20
# 2004    20.81
# 2005    24.76
# 2006    82.74
# 2007    22.72
# 2008    35.82
# 2009    33.00
# 2010    21.82
# 2011    14.76
# 2012    14.03
# 2013    21.40
# 2014    11.98
# 2015    14.24
# 2016     4.77
# 2017     0.03
# 2020     0.29
# Name: Global_Sales, dtype: float64

# %%
sns.barplot(x='Year',y='Global_Sales',data=df,estimator=np.sum)

# %% [markdown]
# 2017 was the lowest year games have been sol accordingg to the dataser

# %%
df.groupby('Year')['Global_Sales'].max()
# Out:
# Year
# 1980     4.31
# 1981     4.50
# 1982     7.81
# 1983     3.20
# 1984    28.31
# 1985    40.24
# 1986     6.51
# 1987     4.38
# 1988    17.28
# 1989    30.26
# 1990    20.61
# 1991     4.61
# 1992    11.18
# 1993    10.55
# 1994     9.30
# 1995     5.15
# 1996    31.37
# 1997    10.95
# 1998    14.64
# 1999    23.10
# 2000     6.39
# 2001    14.98
# 2002    16.15
# 2003     7.20
# 2004    20.81
# 2005    24.76
# 2006    82.74
# 2007    22.72
# 2008    35.82
# 2009    33.00
# 2010    21.82
# 2011    14.76
# 2012    14.03
# 2013    21.40
# 2014    11.98
# 2015    14.24
# 2016     4.77
# 2017     0.03
# 2020     0.29
# Name: Global_Sales, dtype: float64

# %%
Euroupe like action

# %%
df.groupby('Genre')['EU_Sales'].sum()
# Out:
# Genre
# Action          516.48
# Adventure        63.79
# Fighting        100.00
# Misc            213.82
# Platform        200.67
# Puzzle           50.53
# Racing          236.32
# Role-Playing    187.58
# Shooter         310.45
# Simulation      113.20
# Sports          371.34
# Strategy         44.94
# Name: EU_Sales, dtype: float64

# %%
sns.barplot(x='Genre',y='EU_Sales',data=df,estimator=np.sum)

# %%
North America Likes Action Games

# %%
df.groupby('Genre')['NA_Sales'].sum()
# Out:
# Genre
# Action          861.80
# Adventure       102.06
# Fighting        220.74
# Misc            402.48
# Platform        445.99
# Puzzle          122.01
# Racing          356.93
# Role-Playing    326.50
# Shooter         575.16
# Simulation      181.78
# Sports          670.09
# Strategy         67.89
# Name: NA_Sales, dtype: float64

# %%
sns.barplot(x='Genre',y='NA_Sales',data=df,estimator=np.sum)

# %% [markdown]
# Japan Likes Role Playing Games

# %%
df.groupby('Genre')['JP_Sales'].sum()
# Out:
# Genre
# Action          158.66
# Adventure        52.01
# Fighting         87.15
# Misc            106.67
# Platform        130.65
# Puzzle           56.68
# Racing           56.61
# Role-Playing    350.29
# Shooter          38.18
# Simulation       63.54
# Sports          134.76
# Strategy         49.10
# Name: JP_Sales, dtype: float64

# %%
sns.barplot(x='Genre',y='JP_Sales',data=df,estimator=np.sum)

# %%
sns.jointplot(x='Year', y='Global_Sales',data=df)

# %%
df[df['Year'] >= 2010 & df['Year'] >= 2020  ]['Name'].unique()

# %%
sns.countplot(x="Genre", data=df)

# %%
df[df['Global_Sales'] == df['Global_Sales'].min()]

# %% [markdown]
# What is the most selling platform ?

# %%
df['Platform'].value_counts().head(1)

# %%
df[df['Name'] == '%FIFA%']['Year']

# %%
df.groupby('Genre').max('Global_sales')
# Out:
#                Rank    Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action        16592  2017.0      9.63      9.27      3.96        10.57
# Adventure     16594  2016.0      6.16      2.79      2.69         0.83
# Fighting      16566  2016.0      6.75      2.61      2.87         1.41
# Misc          16545  2016.0     14.97      9.26      4.16         2.85
# Platform      16600  2016.0     29.08      9.23      6.81         2.90
# Puzzle        16599  2015.0     23.20      5.36      5.32         1.18
# Racing        16598  2016.0     15.85     12.88      4.13         7.53
# Role-Playing  16593  2017.0     11.27      8.89     10.22         1.74
# Shooter       16597  2016.0     26.93      5.88      1.44         2.52
# Simulation    16595  2020.0      9.07     11.00      5.33         2.75
# Sports        16590  2016.0     41.49     29.02      3.77         8.46
# Strategy      16569  2016.0      3.18      2.27      1.61         0.59
#
#               Global_Sales
# Genre
# ...

# %% [markdown]
# What is the most selling platform ?

# %%
df[df['Global_Sales'] == df['Global_Sales'].max()]
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
x=df[df['Year']>=2010]['Publisher']
df.groupby(x)['Global_Sales'].sum()
# Out:
# Publisher
# 1C Company               0.09
# 505 Games               25.10
# 5pb                      1.35
# 7G//AMES                 0.08
# ASCII Media Works        0.14
#                         ...
# dramatic create          0.11
# iWin                     0.06
# imageepoch Inc.          0.04
# inXile Entertainment     0.10
# mixi, Inc                0.86
# Name: Global_Sales, Length: 264, dtype: float64

# %%
f=pd.pivot_table(df, values='Global_Sales', index='Year', columns='Publisher',aggfunc=np.su

# %%
df
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...
